# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.422421
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** Since W is initialized close to zero, $L_i$ should be close to $-log(\frac{e^0}{\sum_{j=1}^C e^0})$. In the CIFAR-10 dataset, $C = 10$.

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.850489 analytic: -0.850489, relative error: 6.052142e-08
# numerical: -4.388060 analytic: -4.388060, relative error: 6.776675e-09
# numerical: -2.837199 analytic: -2.837199, relative error: 9.167227e-09
# numerical: 3.321364 analytic: 3.321364, relative error: 7.661553e-09
# numerical: -1.582641 analytic: -1.582641, relative error: 1.533341e-08
# numerical: 0.362151 analytic: 0.362151, relative error: 2.352741e-07
# numerical: -6.351038 analytic: -6.351038, relative error: 9.675331e-09
# numerical: 0.900824 analytic: 0.900824, relative error: 3.552303e-10
# numerical: 2.100569 analytic: 2.100569, relative error: 1.894568e-08
# numerical: -2.084800 analytic: -2.084801, relative error: 7.098510e-09
# numerical: -0.515356 analytic: -0.515356, relative error: 1.158977e-07
# numerical: -1.059029 analytic: -1.059029, relative error: 4.991324e-08
# numerical: -0.946306 analytic: -0.946306, relative error: 2.562949e-09
# numerical: 0.988979 analytic: 0.988979, relative error: 2.837705e-08
# numerical: -2.022527 analytic: -2.022528, relative error: 3.277268e-08
# numerical: 0.104688 analytic: 0.104688, relative error: 8.813876e-08
# numerical: -0.665612 analytic: -0.665612, relative error: 5.789003e-08
# numerical: -1.411605 analytic: -1.411605, relative error: 3.221450e-09
# numerical: -0.114692 analytic: -0.114692, relative error: 2.435762e-08
# numerical: 1.951799 analytic: 1.951799, relative error: 2.696224e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.422421e+00 computed in 0.188018s
# vectorized loss: 2.422421e+00 computed in 0.007002s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7,2e-7,3e-7,4e-7,5e-7,1e-6]
regularization_strengths = [1e4, 2e4, 2.5e4, 5e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
for l_rate in learning_rates:
    for reg_val in regularization_strengths:
        print('Validation for l_rate = %f, reg = %f start.'%(l_rate, reg_val))
        softmax_now = Softmax()
        softmax_now.train(X_train, y_train, learning_rate=l_rate, reg=reg_val,
                      num_iters=1500, verbose=True)
        y_pred_train = softmax_now.predict(X_train)
        acc_train_now = np.mean(y_pred_train == y_train)
        y_pred_val = softmax_now.predict(X_val)
        acc_val_now = np.mean(y_pred_val == y_val)
        results[(l_rate, reg_val)] = (acc_train_now, acc_val_now)
        if acc_val_now > best_val:
            best_val = acc_val_now
            best_softmax = softmax_now
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# Validation for l_rate = 0.000000, reg = 10000.000000 start.
# iteration 0 / 1500: loss 310.334331
# iteration 100 / 1500: loss 207.068763
# iteration 200 / 1500: loss 139.039417
# iteration 300 / 1500: loss 93.631972
# iteration 400 / 1500: loss 63.125331
# iteration 500 / 1500: loss 42.976407
# iteration 600 / 1500: loss 29.371759
# iteration 700 / 1500: loss 20.319342
# iteration 800 / 1500: loss 14.224616
# iteration 900 / 1500: loss 10.179460
# iteration 1000 / 1500: loss 7.509207
# iteration 1100 / 1500: loss 5.657793
# iteration 1200 / 1500: loss 4.452381
# iteration 1300 / 1500: loss 3.637302
# iteration 1400 / 1500: loss 3.061503
# Validation for l_rate = 0.000000, reg = 20000.000000 start.
# iteration 0 / 1500: loss 628.663797
# iteration 100 / 1500: loss 281.559440
# iteration 200 / 1500: loss 127.173511
# iteration 300 / 1500: loss 57.901363
# iteration 400 / 1500: loss 27.078717
# iteration 500 / 1500: loss 13.225744
# iteration 600 / 1500: loss 7.110678
# iteration 700 / 1500: loss 4.272830
# iteration 800 / 1500: loss 3.082054
# iteration 900 / 1500: loss 2.470582
# iteration 1000 / 1500: loss 2.268319
# iteration 1100 / 1500: loss 2.110465
# iteration 1200 / 1500: loss 2.065481
# iteration 1300 / 1500: loss 2.101353
# iteration 1400 / 1500: loss 2.048728
# Validation for l_rate = 0.000000, reg = 25000.000000 start.
# iteration 0 / 1500: loss 778.244839
# iteration 100 / 1500: loss 285.437844
# iteration 200 / 1500: loss 105.801536
# iteration 300 / 1500: loss 39.961515
# iteration 400 / 1500: loss 15.943540
# iteration 500 / 1500: loss 7.120637
# iteration 600 / 1500: loss 3.947742
# iteration 700 / 1500: loss 2.744562
# iteration 800 / 1500: loss 2.370630
# iteration 900 / 1500: loss 2.133410
# iteration 1000 / 1500: loss 2.134631
# iteration 1100 / 1500: loss 2.113278
# iteration 1200 / 1500: loss 2.045508
# iteration 1300 / 1500: loss 2.105515
# iteration 1400 / 1500: loss 2.062889
# Validation for l_rate = 0.000000, reg = 50000.000000 start.
# iteration 0 / 1500: loss 1532.029445
# iteration 100 / 1500: loss 206.389885
# iteration 200 / 1500: loss 29.416589
# iteration 300 / 1500: loss 5.784386
# iteration 400 / 1500: loss 2.642676
# iteration 500 / 1500: loss 2.202493
# iteration 600 / 1500: loss 2.163862
# iteration 700 / 1500: loss 2.135395
# iteration 800 / 1500: loss 2.094886
# iteration 900 / 1500: loss 2.190838
# iteration 1000 / 1500: loss 2.166169
# iteration 1100 / 1500: loss 2.129450
# iteration 1200 / 1500: loss 2.165298
# iteration 1300 / 1500: loss 2.137143
# iteration 1400 / 1500: loss 2.149354
# Validation for l_rate = 0.000000, reg = 10000.000000 start.
# iteration 0 / 1500: loss 313.785712
# iteration 100 / 1500: loss 140.665335
# iteration 200 / 1500: loss 63.862508
# iteration 300 / 1500: loss 29.692206
# iteration 400 / 1500: loss 14.297458
# iteration 500 / 1500: loss 7.550842
# iteration 600 / 1500: loss 4.446484
# iteration 700 / 1500: loss 2.984450
# iteration 800 / 1500: loss 2.463516
# iteration 900 / 1500: loss 2.181438
# iteration 1000 / 1500: loss 2.130601
# iteration 1100 / 1500: loss 2.099758
# iteration 1200 / 1500: loss 2.022238
# iteration 1300 / 1500: loss 1.981894
# iteration 1400 / 1500: loss 1.961509
# Validation for l_rate = 0.000000, reg = 20000.000000 start.
# iteration 0 / 1500: loss 619.546730
# iteration 100 / 1500: loss 124.831143
# iteration 200 / 1500: loss 26.576924
# iteration 300 / 1500: loss 6.970385
# iteration 400 / 1500: loss 3.123801
# iteration 500 / 1500: loss 2.301509
# iteration 600 / 1500: loss 2.134358
# iteration 700 / 1500: loss 2.100799
# iteration 800 / 1500: loss 2.052531
# iteration 900 / 1500: loss 2.079840
# iteration 1000 / 1500: loss 2.062587
# iteration 1100 / 1500: loss 2.085653
# iteration 1200 / 1500: loss 2.053926
# iteration 1300 / 1500: loss 2.028904
# iteration 1400 / 1500: loss 2.042737
# Validation for l_rate = 0.000000, reg = 25000.000000 start.
# iteration 0 / 1500: loss 774.622231
# iteration 100 / 1500: loss 104.685525
# iteration 200 / 1500: loss 15.774332
# iteration 300 / 1500: loss 3.873927
# iteration 400 / 1500: loss 2.284220
# iteration 500 / 1500: loss 2.111156
# iteration 600 / 1500: loss 2.076376
# iteration 700 / 1500: loss 2.145460
# iteration 800 / 1500: loss 2.132502
# iteration 900 / 1500: loss 2.064237
# iteration 1000 / 1500: loss 2.126192
# iteration 1100 / 1500: loss 2.029396
# iteration 1200 / 1500: loss 2.086728
# iteration 1300 / 1500: loss 2.097492
# iteration 1400 / 1500: loss 2.116045
# Validation for l_rate = 0.000000, reg = 50000.000000 start.
# iteration 0 / 1500: loss 1522.968693
# iteration 100 / 1500: loss 28.697014
# iteration 200 / 1500: loss 2.618429
# iteration 300 / 1500: loss 2.161807
# iteration 400 / 1500: loss 2.115837
# iteration 500 / 1500: loss 2.117690
# iteration 600 / 1500: loss 2.159734
# iteration 700 / 1500: loss 2.116800
# iteration 800 / 1500: loss 2.144298
# iteration 900 / 1500: loss 2.181319
# iteration 1000 / 1500: loss 2.120131
# iteration 1100 / 1500: loss 2.143379
# iteration 1200 / 1500: loss 2.146589
# iteration 1300 / 1500: loss 2.113743
# iteration 1400 / 1500: loss 2.139677
# Validation for l_rate = 0.000000, reg = 10000.000000 start.
# iteration 0 / 1500: loss 313.179631
# iteration 100 / 1500: loss 94.173007
# iteration 200 / 1500: loss 29.537645
# iteration 300 / 1500: loss 10.161646
# iteration 400 / 1500: loss 4.452869
# iteration 500 / 1500: loss 2.736178
# iteration 600 / 1500: loss 2.258880
# iteration 700 / 1500: loss 2.089311
# iteration 800 / 1500: loss 1.999640
# iteration 900 / 1500: loss 1.997728
# iteration 1000 / 1500: loss 1.898072
# iteration 1100 / 1500: loss 1.975716
# iteration 1200 / 1500: loss 2.005932
# iteration 1300 / 1500: loss 2.025808
# iteration 1400 / 1500: loss 1.997816
# Validation for l_rate = 0.000000, reg = 20000.000000 start.
# iteration 0 / 1500: loss 620.864995
# iteration 100 / 1500: loss 56.901050
# iteration 200 / 1500: loss 6.978017
# iteration 300 / 1500: loss 2.507516
# iteration 400 / 1500: loss 2.159865
# iteration 500 / 1500: loss 2.093195
# iteration 600 / 1500: loss 2.099594
# iteration 700 / 1500: loss 2.094678
# iteration 800 / 1500: loss 2.010318
# iteration 900 / 1500: loss 2.112738
# iteration 1000 / 1500: loss 2.051569
# iteration 1100 / 1500: loss 2.060985
# iteration 1200 / 1500: loss 1.995378
# iteration 1300 / 1500: loss 2.069427
# iteration 1400 / 1500: loss 2.059736
# Validation for l_rate = 0.000000, reg = 25000.000000 start.
# iteration 0 / 1500: loss 773.630348
# iteration 100 / 1500: loss 39.315529
# iteration 200 / 1500: loss 3.940540
# iteration 300 / 1500: loss 2.139319
# iteration 400 / 1500: loss 2.030031
# iteration 500 / 1500: loss 2.072297
# iteration 600 / 1500: loss 2.003214
# iteration 700 / 1500: loss 2.056832
# iteration 800 / 1500: loss 2.077018
# iteration 900 / 1500: loss 2.008893
# iteration 1000 / 1500: loss 2.110702
# iteration 1100 / 1500: loss 2.035239
# iteration 1200 / 1500: loss 2.085723
# iteration 1300 / 1500: loss 2.045225
# iteration 1400 / 1500: loss 2.134793
# Validation for l_rate = 0.000000, reg = 50000.000000 start.
# iteration 0 / 1500: loss 1533.993905
# iteration 100 / 1500: loss 5.557874
# iteration 200 / 1500: loss 2.181858
# iteration 300 / 1500: loss 2.113061
# iteration 400 / 1500: loss 2.164361
# iteration 500 / 1500: loss 2.149874
# iteration 600 / 1500: loss 2.165182
# iteration 700 / 1500: loss 2.162375
# iteration 800 / 1500: loss 2.147911
# iteration 900 / 1500: loss 2.122209
# iteration 1000 / 1500: loss 2.119943
# iteration 1100 / 1500: loss 2.170031
# iteration 1200 / 1500: loss 2.186659
# iteration 1300 / 1500: loss 2.159670
# iteration 1400 / 1500: loss 2.098955
# Validation for l_rate = 0.000000, reg = 10000.000000 start.
# iteration 0 / 1500: loss 308.253119
# iteration 100 / 1500: loss 62.373420
# iteration 200 / 1500: loss 14.111078
# iteration 300 / 1500: loss 4.375404
# iteration 400 / 1500: loss 2.492857
# iteration 500 / 1500: loss 2.098854
# iteration 600 / 1500: loss 2.071323
# iteration 700 / 1500: loss 2.057050
# iteration 800 / 1500: loss 1.972403
# iteration 900 / 1500: loss 2.009278
# iteration 1000 / 1500: loss 2.011537
# iteration 1100 / 1500: loss 2.118761
# iteration 1200 / 1500: loss 2.035630
# iteration 1300 / 1500: loss 1.996273
# iteration 1400 / 1500: loss 1.981215
# Validation for l_rate = 0.000000, reg = 20000.000000 start.
# iteration 0 / 1500: loss 623.106744
# iteration 100 / 1500: loss 26.459314
# iteration 200 / 1500: loss 3.048237
# iteration 300 / 1500: loss 2.108463
# iteration 400 / 1500: loss 2.068073
# iteration 500 / 1500: loss 2.044567
# iteration 600 / 1500: loss 2.084022
# iteration 700 / 1500: loss 2.029949
# iteration 800 / 1500: loss 2.075543
# iteration 900 / 1500: loss 2.086589
# iteration 1000 / 1500: loss 2.085015
# iteration 1100 / 1500: loss 2.037856
# iteration 1200 / 1500: loss 2.055804
# iteration 1300 / 1500: loss 2.047625
# iteration 1400 / 1500: loss 2.073803
# Validation for l_rate = 0.000000, reg = 25000.000000 start.
# iteration 0 / 1500: loss 787.080353
# iteration 100 / 1500: loss 15.730014
# iteration 200 / 1500: loss 2.371042
# iteration 300 / 1500: loss 2.116140
# iteration 400 / 1500: loss 2.089018
# iteration 500 / 1500: loss 2.106109
# iteration 600 / 1500: loss 2.118425
# iteration 700 / 1500: loss 2.069666
# iteration 800 / 1500: loss 2.057573
# iteration 900 / 1500: loss 2.129778
# iteration 1000 / 1500: loss 2.073115
# iteration 1100 / 1500: loss 2.077824
# iteration 1200 / 1500: loss 2.041753
# iteration 1300 / 1500: loss 2.095091
# iteration 1400 / 1500: loss 2.124060
# Validation for l_rate = 0.000000, reg = 50000.000000 start.
# iteration 0 / 1500: loss 1549.207586
# iteration 100 / 1500: loss 2.628232
# iteration 200 / 1500: loss 2.213040
# iteration 300 / 1500: loss 2.175359
# iteration 400 / 1500: loss 2.109932
# iteration 500 / 1500: loss 2.141785
# iteration 600 / 1500: loss 2.183497
# iteration 700 / 1500: loss 2.137044
# iteration 800 / 1500: loss 2.153830
# iteration 900 / 1500: loss 2.158576
# iteration 1000 / 1500: loss 2.147206
# iteration 1100 / 1500: loss 2.162614
# iteration 1200 / 1500: loss 2.209990
# iteration 1300 / 1500: loss 2.182014
# iteration 1400 / 1500: loss 2.137243
# Validation for l_rate = 0.000000, reg = 10000.000000 start.
# iteration 0 / 1500: loss 314.700897
# iteration 100 / 1500: loss 43.179578
# iteration 200 / 1500: loss 7.448264
# iteration 300 / 1500: loss 2.771476
# iteration 400 / 1500: loss 2.154951
# iteration 500 / 1500: loss 1.963646
# iteration 600 / 1500: loss 2.029855
# iteration 700 / 1500: loss 2.092703
# iteration 800 / 1500: loss 2.010792
# iteration 900 / 1500: loss 2.022446
# iteration 1000 / 1500: loss 2.044152
# iteration 1100 / 1500: loss 2.019482
# iteration 1200 / 1500: loss 2.039099
# iteration 1300 / 1500: loss 2.016889
# iteration 1400 / 1500: loss 2.050435
# Validation for l_rate = 0.000000, reg = 20000.000000 start.
# iteration 0 / 1500: loss 619.997440
# iteration 100 / 1500: loss 12.753461
# iteration 200 / 1500: loss 2.255073
# iteration 300 / 1500: loss 2.085043
# iteration 400 / 1500: loss 2.119607
# iteration 500 / 1500: loss 2.104927
# iteration 600 / 1500: loss 2.063549
# iteration 700 / 1500: loss 2.084123
# iteration 800 / 1500: loss 2.061395
# iteration 900 / 1500: loss 2.021262
# iteration 1000 / 1500: loss 2.111479
# iteration 1100 / 1500: loss 2.120346
# iteration 1200 / 1500: loss 2.084560
# iteration 1300 / 1500: loss 2.087960
# iteration 1400 / 1500: loss 2.047586
# Validation for l_rate = 0.000000, reg = 25000.000000 start.
# iteration 0 / 1500: loss 778.618026
# iteration 100 / 1500: loss 6.899290
# iteration 200 / 1500: loss 2.090472
# iteration 300 / 1500: loss 2.099333
# iteration 400 / 1500: loss 2.124026
# iteration 500 / 1500: loss 2.061095
# iteration 600 / 1500: loss 2.154483
# iteration 700 / 1500: loss 2.087289
# iteration 800 / 1500: loss 2.171036
# iteration 900 / 1500: loss 2.136123
# iteration 1000 / 1500: loss 2.086542
# iteration 1100 / 1500: loss 2.140920
# iteration 1200 / 1500: loss 2.087259
# iteration 1300 / 1500: loss 2.130154
# iteration 1400 / 1500: loss 2.136657
# Validation for l_rate = 0.000000, reg = 50000.000000 start.
# iteration 0 / 1500: loss 1535.096943
# iteration 100 / 1500: loss 2.166211
# iteration 200 / 1500: loss 2.098917
# iteration 300 / 1500: loss 2.160757
# iteration 400 / 1500: loss 2.123765
# iteration 500 / 1500: loss 2.171893
# iteration 600 / 1500: loss 2.152793
# iteration 700 / 1500: loss 2.153999
# iteration 800 / 1500: loss 2.172550
# iteration 900 / 1500: loss 2.162800
# iteration 1000 / 1500: loss 2.180293
# iteration 1100 / 1500: loss 2.126142
# iteration 1200 / 1500: loss 2.146024
# iteration 1300 / 1500: loss 2.175405
# iteration 1400 / 1500: loss 2.133418
# Validation for l_rate = 0.000001, reg = 10000.000000 start.
# iteration 0 / 1500: loss 315.161992
# iteration 100 / 1500: loss 7.393559
# iteration 200 / 1500: loss 2.096394
# iteration 300 / 1500: loss 1.992195
# iteration 400 / 1500: loss 1.928373
# iteration 500 / 1500: loss 2.091812
# iteration 600 / 1500: loss 2.011788
# iteration 700 / 1500: loss 2.059207
# iteration 800 / 1500: loss 2.038953
# iteration 900 / 1500: loss 2.043708
# iteration 1000 / 1500: loss 2.027968
# iteration 1100 / 1500: loss 1.951750
# iteration 1200 / 1500: loss 1.959545
# iteration 1300 / 1500: loss 2.006845
# iteration 1400 / 1500: loss 1.972625
# Validation for l_rate = 0.000001, reg = 20000.000000 start.
# iteration 0 / 1500: loss 616.874699
# iteration 100 / 1500: loss 2.227975
# iteration 200 / 1500: loss 2.038156
# iteration 300 / 1500: loss 2.034030
# iteration 400 / 1500: loss 2.101968
# iteration 500 / 1500: loss 2.070484
# iteration 600 / 1500: loss 2.077353
# iteration 700 / 1500: loss 2.079125
# iteration 800 / 1500: loss 2.130352
# iteration 900 / 1500: loss 2.046620
# iteration 1000 / 1500: loss 2.126851
# iteration 1100 / 1500: loss 2.014896
# iteration 1200 / 1500: loss 2.007815
# iteration 1300 / 1500: loss 2.089908
# iteration 1400 / 1500: loss 2.063094
# Validation for l_rate = 0.000001, reg = 25000.000000 start.
# iteration 0 / 1500: loss 774.009231
# iteration 100 / 1500: loss 2.109417
# iteration 200 / 1500: loss 2.134828
# iteration 300 / 1500: loss 2.073977
# iteration 400 / 1500: loss 2.102200
# iteration 500 / 1500: loss 2.079157
# iteration 600 / 1500: loss 2.105877
# iteration 700 / 1500: loss 2.115914
# iteration 800 / 1500: loss 2.061768
# iteration 900 / 1500: loss 2.125411
# iteration 1000 / 1500: loss 2.131441
# iteration 1100 / 1500: loss 2.118449
# iteration 1200 / 1500: loss 2.105667
# iteration 1300 / 1500: loss 2.094068
# iteration 1400 / 1500: loss 2.133747
# Validation for l_rate = 0.000001, reg = 50000.000000 start.
# iteration 0 / 1500: loss 1561.857944
# iteration 100 / 1500: loss 2.118460
# iteration 200 / 1500: loss 2.173158
# iteration 300 / 1500: loss 2.164983
# iteration 400 / 1500: loss 2.131115
# iteration 500 / 1500: loss 2.162748
# iteration 600 / 1500: loss 2.147069
# iteration 700 / 1500: loss 2.148894
# iteration 800 / 1500: loss 2.187001
# iteration 900 / 1500: loss 2.210872
# iteration 1000 / 1500: loss 2.157282
# iteration 1100 / 1500: loss 2.160130
# iteration 1200 / 1500: loss 2.108755
# iteration 1300 / 1500: loss 2.102272
# iteration 1400 / 1500: loss 2.167302
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.347286 val accuracy: 0.360000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.334449 val accuracy: 0.359000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.329755 val accuracy: 0.337000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.308694 val accuracy: 0.325000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.356878 val accuracy: 0.364000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.340347 val accuracy: 0.356000
# lr 2.000000e-07 reg 2.500000e+04 train accuracy: 0.325061 val accuracy: 0.340000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.300143 val accuracy: 0.315000
# lr 3.000000e-07 reg 1.000000e+04 train accuracy: 0.359388 val accuracy: 0.380000
# lr 3.000000e-07 reg 2.000000e+04 train accuracy: 0.332041 val accuracy: 0.336000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.329571 val accuracy: 0.350000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.315265 val accuracy: 0.334000
# lr 4.000000e-07 reg 1.000000e+04 train accuracy: 0.361959 val accuracy: 0.373000
# lr 4.000000e-07 reg 2.000000e+04 train accuracy: 0.327980 val accuracy: 0.344000
# lr 4.000000e-07 reg 2.500000e+04 train accuracy: 0.325796 val accuracy: 0.346000
# lr 4.000000e-07 reg 5.000000e+04 train accuracy: 0.304020 val accuracy: 0.318000
# lr 5.000000e-07 reg 1.000000e+04 train accuracy: 0.350163 val accuracy: 0.360000
# lr 5.000000e-07 reg 2.000000e+04 train accuracy: 0.331857 val accuracy: 0.346000
# lr 5.000000e-07 reg 2.500000e+04 train accuracy: 0.333673 val accuracy: 0.344000
# lr 5.000000e-07 reg 5.000000e+04 train accuracy: 0.304306 val accuracy: 0.311000
# lr 1.000000e-06 reg 1.000000e+04 train accuracy: 0.354490 val accuracy: 0.363000
# lr 1.000000e-06 reg 2.000000e+04 train accuracy: 0.323776 val accuracy: 0.333000
# lr 1.000000e-06 reg 2.500000e+04 train accuracy: 0.324531 val accuracy: 0.331000
# lr 1.000000e-06 reg 5.000000e+04 train accuracy: 0.297143 val accuracy: 0.319000
# best validation accuracy achieved during cross-validation: 0.380000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.369000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
